# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional, Conv1D, Flatten
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Potencia generada')
    plt.plot(predicted, color='blue',label='Predicción')
    plt.title('Predicción LSTM')
    plt.xlabel('Time')
    plt.ylabel('Salida')
    plt.legend()
    plt.show()

# %%
df_Plant1_Generation = pd.read_csv("Plant_1_Generation_Data.csv", sep = ",",low_memory = False , encoding = 'utf_8')
df_Plant1_Weather = pd.read_csv("Plant_1_Weather_Sensor_Data.csv", sep = ",",low_memory = False , encoding = 'utf_8')
df_Plant2_Generation = pd.read_csv("Plant_2_Generation_Data.csv", sep = ",",  low_memory = False , encoding = 'utf_8')
df_Plant2_Weather = pd.read_csv("Plant_2_Weather_Sensor_Data.csv", sep = ",",  low_memory = False , encoding = 'utf_8')

# %%
df_Plant1_Generation
# Out:
#               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0      15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1      15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2      15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3      15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4      15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# ...                 ...       ...              ...       ...       ...
# 68773  17-06-2020 23:45   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774  17-06-2020 23:45   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775  17-06-2020 23:45   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776  17-06-2020 23:45   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777  17-06-2020 23:45   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 0            0.000    6259559.0
# 1            0.000    6183645.0
# 2            0.000    6987759.0
# 3            0.000    7602960.0
# 4            0.000    7158964.0
# ...            ...          ...
# 68773     5967.000    7287002.0
# 68774     5147.625    7028601.0
# 68775     5819.000    7251204.0
# 68776     5817.000    6583369.0
# 68777     5910.000    7363272.0
#
# [68778 rows x 7 columns]

# %%
df_Plant1_Generation.drop(['SOURCE_KEY','PLANT_ID'],axis = 1 , inplace = True)
df_Plant1_Weather.drop(['SOURCE_KEY','PLANT_ID'],axis = 1 , inplace = True)
df_Plant2_Generation.drop(['SOURCE_KEY','PLANT_ID'],axis = 1 , inplace = True)
df_Plant2_Weather.drop(['SOURCE_KEY','PLANT_ID'],axis = 1 , inplace = True)

# %%
#Formato de fecha
df_Plant1_Generation['DATE_TIME']= pd.to_datetime(df_Plant1_Generation['DATE_TIME'])
df_Plant1_Weather['DATE_TIME']= pd.to_datetime(df_Plant1_Weather['DATE_TIME'])
df_Plant2_Generation['DATE_TIME']= pd.to_datetime(df_Plant2_Generation['DATE_TIME'])
df_Plant2_Weather['DATE_TIME']= pd.to_datetime(df_Plant2_Weather['DATE_TIME'])

# %%
plant1 = pd.merge(df_Plant1_Generation, df_Plant1_Weather, how='inner', on = 'DATE_TIME')
plant2 = pd.merge(df_Plant2_Generation, df_Plant2_Weather, how='inner', on = 'DATE_TIME')

# %%
df_generation = pd.concat([plant1,plant2], axis= 0)

# %%
plant1.head()
# Out:
#    DATE_TIME  DC_POWER  AC_POWER  DAILY_YIELD  TOTAL_YIELD  \
# 0 2020-05-15       0.0       0.0          0.0    6259559.0
# 1 2020-05-15       0.0       0.0          0.0    6183645.0
# 2 2020-05-15       0.0       0.0          0.0    6987759.0
# 3 2020-05-15       0.0       0.0          0.0    7602960.0
# 4 2020-05-15       0.0       0.0          0.0    7158964.0
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0            25.184316           22.857507          0.0
# 1            25.184316           22.857507          0.0
# 2            25.184316           22.857507          0.0
# 3            25.184316           22.857507          0.0
# 4            25.184316           22.857507          0.0

# %%
plant1.shape
# Out:
# (45680, 8)

# %%
df_generation.shape
# Out:
# (113378, 8)

# %%
features = df_generation[['AC_POWER','DAILY_YIELD','TOTAL_YIELD','AMBIENT_TEMPERATURE','IRRADIATION']].copy()

# %%
features.index = df_generation['DATE_TIME']

# %%
features
# Out:
#                      AC_POWER  DAILY_YIELD  TOTAL_YIELD  AMBIENT_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00       0.0          0.0    6259559.0            25.184316
# 2020-05-15 00:00:00       0.0          0.0    6183645.0            25.184316
# 2020-05-15 00:00:00       0.0          0.0    6987759.0            25.184316
# 2020-05-15 00:00:00       0.0          0.0    7602960.0            25.184316
# 2020-05-15 00:00:00       0.0          0.0    7158964.0            25.184316
# ...                       ...          ...          ...                  ...
# 2020-06-17 23:45:00       0.0       4157.0     520758.0            23.202871
# 2020-06-17 23:45:00       0.0       3931.0  121131356.0            23.202871
# 2020-06-17 23:45:00       0.0       4322.0    2427691.0            23.202871
# 2020-06-17 23:45:00       0.0       4218.0  106896394.0            23.202871
# 2020-06-17 23:45:00       0.0       4316.0  209335741.0            23.202871
#
#                      IRRADIATION
# DATE_TIME
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:00:00          0.0
# ...                          ...
# 2020-06-17 23:45:00          0.0
# 2020-06-17 23:45:00          0.0
# 2020-06-17 23:45:00          0.0
# 2020-06-17 23:45:00          0.0
# 2020-06-17 23:45:00          0.0
#
# [113378 rows x 5 columns]

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 113378 entries, 2020-05-15 00:00:00 to 2020-06-17 23:45:00
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   AC_POWER             113378 non-null  float64
#  1   DAILY_YIELD          113378 non-null  float64
#  2   TOTAL_YIELD          113378 non-null  float64
#  3   AMBIENT_TEMPERATURE  113378 non-null  float64
#  4   IRRADIATION          113378 non-null  float64
# dtypes: float64(5)
# memory usage: 5.2 MB

# %%
training_set = features[:'2020-06-12'].iloc[:,0:5]
test_set = features['2020-06-13':].iloc[:,0:5]

# %%
training_set.shape
# Out:
# (92302, 5)

# %%
test_set.shape
# Out:
# (21076, 5)

# %%
features['AC_POWER'][:'2020-06-12'].plot(figsize=(16,4),legend=True)
features[['AC_POWER']]['2020-06-13':].plot(figsize=(16,4),legend=True)
plt.title('Generación')
plt.show()

# %%
scaler = StandardScaler()
scaler = scaler.fit(training_set)
training_set_scaled = scaler.transform(training_set)

# %%
X_train = []
y_train = []
n_future = 1 #vector
n_past = 60
for i in range(n_past,len(training_set_scaled)):

  X_train.append(training_set_scaled[i-n_past:i,0:training_set_scaled.shape[1]])
  y_train.append(training_set_scaled[i+n_future-1:i + n_future,0])

X_train, y_train = np.array(X_train),np.array(y_train)
print(X_train.shape)
print(y_train.shape)
# Out:
# (92242, 60, 5)
# (92242, 1)

# %% [markdown]
# ##**GRU**

# %%
#Arquitectura GRU
regressorGRU = Sequential()

regressorGRU.add(GRU(64, return_sequences=True,input_shape=(X_train.shape[1],5)))
regressorGRU.add(Dropout(0.2)) #Se agregaron dropout luego de primera ejecuc
regressorGRU.add(GRU(64, return_sequences=True))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(64, return_sequences=True))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(64))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(Dense(1))

# %%
regressorGRU.compile(optimizer=SGD(learning_rate=0.01,momentum=0.9),loss='mean_squared_error',metrics=['mean_squared_error'])
regressorGRU.fit(X_train,y_train,epochs=20,batch_size=32)
# Out:
# Epoch 1/20
# 2883/2883 [==============================] - 44s 12ms/step - loss: 0.2238 - mean_squared_error: 0.2238
# Epoch 2/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.2119 - mean_squared_error: 0.2119
# Epoch 3/20
# 2883/2883 [==============================] - 36s 12ms/step - loss: 0.2061 - mean_squared_error: 0.2061
# Epoch 4/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.2012 - mean_squared_error: 0.2012
# Epoch 5/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1969 - mean_squared_error: 0.1969
# Epoch 6/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1899 - mean_squared_error: 0.1899
# Epoch 7/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1842 - mean_squared_error: 0.1842
# Epoch 8/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1780 - mean_squared_error: 0.1780
# Epoch 9/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1738 - mean_squared_error: 0.1738
# Epoch 10/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1706 - mean_squared_error: 0.1706
# Epoch 11/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1668 - mean_squared_error: 0.1668
# Epoch 12/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1613 - mean_squared_error: 0.1613
# Epoch 13/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1557 - mean_squared_error: 0.1557
# Epoch 14/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1494 - mean_squared_error: 0.1494
# Epoch 15/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1444 - mean_squared_error: 0.1444
# Epoch 16/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1386 - mean_squared_error: 0.1386
# Epoch 17/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1328 - mean_squared_error: 0.1328
# Epoch 18/20
# 2883/2883 [==============================] - 35s 12ms/step - loss: 0.1248 - mean_squared_error: 0.1248
# Epoch 19/20
# 2883/2883 [==============================] - 38s 13ms/step - loss: 0.1187 - mean_squared_error: 0.1187
# Epoch 20/20
# 2883/2883 [==============================] - 36s 12ms/step - loss: 0.1117 - mean_squared_error: 0.1117

# %%
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
dataset_total = pd.concat((features[['AC_POWER','DAILY_YIELD','TOTAL_YIELD','AMBIENT_TEMPERATURE','IRRADIATION']][:'2020-06-12'],
                           features[['AC_POWER','DAILY_YIELD','TOTAL_YIELD','AMBIENT_TEMPERATURE','IRRADIATION']]['2020-06-13':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
print(inputs.shape)

inputs = inputs.reshape(-1,5)
inputs  = scaler.transform(inputs)
# Out:
# (21136, 5)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
print(inputs.shape)
# Out:
# (21136, 5)

# %%
X_test = []
for i in range(60,21136):
    X_test.append(inputs[i-60:i,0:5])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],5))
print(X_test.shape)
#predicted = regressorGRU.predict(X_test)
#predicted = predicted.reshape((predicted.shape[0],predicted.shape[1]))
# Out:
# (21076, 60, 5)

# %%
predicted2 = predicted[:,0]

# %%
predicted2.shape
# Out:
# (10516,)

# %%
predicted2_copies_array = np.repeat(predicted2,5, axis=-1)

# %%
predicted2_copies_array.shape
# Out:
# (52580,)

# %%
conv_predicted = scaler.inverse_transform(np.reshape(predicted2_copies_array,(len(predicted2),5)))

# %%
conv_predicted[:,0].shape
# Out:
# (10516,)

# %%
plt.figure(figsize=(16,5))
plt.plot(np.array(test_set)[:,0],label='test')
plt.plot(conv_predicted[:,0],label="predicción", linestyle = ':')
plt.legend(loc='best')
plt.title("Predicción generación de potencia planta 1 - GRU")
plt.show()

# %%
test_set.shape
# Out:
# (10516, 5)

# %%
predicted.shape
# Out:
# (251, 60, 1)

# %%
inputs.shape
# Out:
# (10576, 5)

# %% [markdown]
# #**LSTM**

# %%
#Arquitectura LSTM
regressorLSTM = Sequential()

regressorLSTM.add(LSTM(64, return_sequences=True,input_shape=(X_train.shape[1],5)))
regressorLSTM.add(Dropout(0.2)) #Se agregaron dropout luego de primera ejecuc
regressorLSTM.add(LSTM(64, return_sequences=True))
regressorLSTM.add(Dropout(0.2))
regressorLSTM.add(LSTM(64, return_sequences=True))
regressorLSTM.add(Dropout(0.2))
regressorLSTM.add(LSTM(64))
regressorLSTM.add(Dropout(0.2))
regressorLSTM.add(Dense(1))

# %%
regressorLSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 64)            17920
#
#  dropout_4 (Dropout)         (None, 60, 64)            0
#
#  lstm_1 (LSTM)               (None, 60, 64)            33024
#
#  dropout_5 (Dropout)         (None, 60, 64)            0
#
#  lstm_2 (LSTM)               (None, 60, 64)            33024
#
#  dropout_6 (Dropout)         (None, 60, 64)            0
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 117,057
# Trainable params: 117,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressorLSTM.compile(optimizer=SGD(learning_rate=0.01,momentum=0.9),loss='mean_squared_error')
regressorLSTM.fit(X_train,y_train,epochs=20,batch_size=32)
# Out:
# Epoch 1/20
# 2883/2883 [==============================] - 44s 13ms/step - loss: 0.2207
# Epoch 2/20
# 2883/2883 [==============================] - 39s 14ms/step - loss: 0.2069
# Epoch 3/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1997
# Epoch 4/20
# 2883/2883 [==============================] - 39s 14ms/step - loss: 0.1934
# Epoch 5/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1862
# Epoch 6/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1808
# Epoch 7/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1750
# Epoch 8/20
# 2883/2883 [==============================] - 38s 13ms/step - loss: 0.1717
# Epoch 9/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1692
# Epoch 10/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1652
# Epoch 11/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1625
# Epoch 12/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1586
# Epoch 13/20
# 2883/2883 [==============================] - 38s 13ms/step - loss: 0.1570
# Epoch 14/20
# 2883/2883 [==============================] - 40s 14ms/step - loss: 0.1540
# Epoch 15/20
# 2883/2883 [==============================] - 40s 14ms/step - loss: 0.1503
# Epoch 16/20
# 2883/2883 [==============================] - 39s 13ms/step - loss: 0.1466
# Epoch 17/20
# 2883/2883 [==============================] - 38s 13ms/step - loss: 0.1438
# Epoch 18/20
# 2883/2883 [==============================] - 38s 13ms/step - loss: 0.1396
# Epoch 19/20
# 2883/2883 [==============================] - 38s 13ms/step - loss: 0.1361
# Epoch 20/20
# 2883/2883 [==============================] - 38s 13ms/step - loss: 0.1320

# %%
predictedLSTM = regressorLSTM.predict(X_test)

# %%
predicted2LSTM = predictedLSTM[:,0]

# %%
predicted2LSTM_copies_array = np.repeat(predicted2LSTM,5, axis=-1)

# %%
predicted2LSTM_copies_array.shape
# Out:
# (105380,)

# %%
conv_predictedLSTM = scaler.inverse_transform(np.reshape(predicted2LSTM_copies_array,(len(predicted2LSTM),5)))

# %%
conv_predictedLSTM.shape
# Out:
# (21076, 5)

# %%
test_set.shape
# Out:
# (21076, 5)

# %%
plt.figure(figsize=(16,5))
plt.plot(np.array(test_set)[:,0],label='test')
plt.plot(conv_predictedLSTM[:,0],label="predicción", linestyle = ':')
plt.legend(loc='best')
plt.title("Predicción generación de potencia - LSTM")
plt.show()

# %%
##RMSE
print(return_rmse(np.array(test_set)[:,0],conv_predictedLSTM[:,0]))
# Out:
# The root mean squared error is 112.194949811085.
# None

# %% [markdown]
# ##**CONV**

# %%
#Arquitectura convolucional
regressorCONV = Sequential()

regressorCONV.add(Conv1D(64, kernel_size=3,input_shape=(X_train.shape[1],5)))
regressorCONV.add(Dropout(0.2)) #Se agregaron dropout luego de primera ejecuc
regressorCONV.add(Conv1D(64, kernel_size=3,input_shape=(X_train.shape[1],5)))#se debe poner el mismo input shape en todas las capas
regressorCONV.add(Dropout(0.2))
regressorCONV.add(Conv1D(64, kernel_size=3,input_shape=(X_train.shape[1],5)))
regressorCONV.add(Dropout(0.2))
#regressorCONV.add(Conv1D(64,kernel_size=3,input_shape=(X_train.shape[1],5)))
#regressorCONV.add(Dropout(0.2))
regressorCONV.add(Flatten())
regressorCONV.add(Dense(1))

# %%
regressorCONV.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 58, 64)            1024
#
#  dropout_8 (Dropout)         (None, 58, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 56, 64)            12352
#
#  dropout_9 (Dropout)         (None, 56, 64)            0
#
#  conv1d_2 (Conv1D)           (None, 54, 64)            12352
#
#  dropout_10 (Dropout)        (None, 54, 64)            0
#
#  flatten (Flatten)           (None, 3456)              0
#
#  dense_2 (Dense)             (None, 1)                 3457
#
# =================================================================
# Total params: 29,185
# Trainable params: 29,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
#loss = Nan en la primera ejecución, se redujo la tasa de aprendizaje y se corrigió

# %%
regressorCONV.compile(optimizer=SGD(learning_rate=0.001,momentum=0.9),loss='mean_squared_error')
regressorCONV.fit(X_train,y_train,epochs=20,batch_size=32)
# Out:
# Epoch 1/20
# 2883/2883 [==============================] - 16s 3ms/step - loss: 0.1412
# Epoch 2/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.1025
# Epoch 3/20
# 2883/2883 [==============================] - 10s 4ms/step - loss: 0.0957
# Epoch 4/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0925
# Epoch 5/20
# 2883/2883 [==============================] - 10s 4ms/step - loss: 0.0910
# Epoch 6/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0900
# Epoch 7/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0885
# Epoch 8/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0879
# Epoch 9/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0866
# Epoch 10/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0875
# Epoch 11/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0860
# Epoch 12/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0850
# Epoch 13/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0865
# Epoch 14/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0857
# Epoch 15/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0851
# Epoch 16/20
# 2883/2883 [==============================] - 12s 4ms/step - loss: 0.0848
# Epoch 17/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0841
# Epoch 18/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0845
# Epoch 19/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0846
# Epoch 20/20
# 2883/2883 [==============================] - 9s 3ms/step - loss: 0.0839

# %%
predictedCONV = regressorCONV.predict(X_test)

# %%
predicted2CONV = predictedCONV[:,0]

# %%
predicted2CONV_copies_array = np.repeat(predicted2CONV,5, axis=-1)

# %%
predicted2CONV_copies_array.shape
# Out:
# (105380,)

# %%
conv_predictedCONV = scaler.inverse_transform(np.reshape(predicted2CONV_copies_array,(len(predicted2CONV),5)))

# %%
plt.figure(figsize=(16,5))
plt.plot(np.array(test_set)[:,0],label='test')
plt.plot(conv_predictedCONV[:,0],label="predicción", linestyle = ':')
plt.legend(loc='best')
plt.title("Predicción generación de potencia - Convolucional")
plt.show()

# %%
print(return_rmse(np.array(test_set)[:,0],conv_predictedCONV[:,0]))
# Out:
# The root mean squared error is 83.05853636932237.
# None
